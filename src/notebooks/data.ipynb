# %% [markdown]
# ## Data

# %%
import pandas as pd

# %%
# wikipedia

wiki = pd.read_csv('../data/wikipedia_data.csv')

# %%
timeseries = wiki.loc[wiki['date'] == '6/01/2016']

# %%
timeseries.groupby(by = ['language', 'access', 'agent']).count()
# Out:
#                            project  article  granularity  date  views  Purpose
# language access    agent
# de       desktop   spider       38       38           38    38     38       38
#                    user         38       38           38    38     38       38
#          mobileapp user         30       30           30    30     30       30
#          mobileweb spider       24       24           24    24     24       24
#                    user         38       38           38    38     38       38
# en       desktop   spider       93       93           93    93     93       93
#                    user         93       93           93    93     93       93
#          mobileapp user         74       74           74    74     74       74
#          mobileweb spider       92       92           92    92     92       92
#                    user         93       93           93    93     93       93
# es       desktop   spider       38       38           38    38     38       38
# ...
